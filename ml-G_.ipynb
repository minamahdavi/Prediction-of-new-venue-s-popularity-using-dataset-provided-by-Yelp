# %%
import seaborn as sns
sns.set()

# %%
from static_grader import grader

# %% [markdown]
# # ML: Predicting Star Ratings

# %% [markdown]
# Our objective is to predict a new venue's popularity from information available when the venue opens.  We will do this by machine learning from a data set of venue popularities provided by Yelp.  The data set contains meta data about the venue (where it is located, the type of food served, etc.).  It also contains a star rating. Note that the venues are not limited to restaurants. This tutorial will walk you through one way to build a machine learning algorithm.

# %% [markdown]
# ## Metrics and scoring

# %% [markdown]
# For most questions, you are asked to submit your models `predict` method to the grader. The grader uses a test set to evaluate your model's performance against our reference solution, using the $R^2$ score. It **is** possible to receive a score greater than one, indicating that you've beaten our reference model. We compare our model's score on a test set to your score on the same test set. See how high you can go!

# %% [markdown]
# ## Download and parse the incoming data

# %% [markdown]
# We start by downloading the data set from Amazon S3:

# %%
# !aws s3 sync s3://dataincubator-course/mldata/ . --exclude '*' --include 'yelp_train_academic_dataset_business.json.gz'

# %% [markdown]
# The training data are a series of JSON objects, in a Gzipped file. Python supports Gzipped files natively: [`gzip.open`](https://docs.python.org/3/library/gzip.html) has the same interface as `open`, but handles `.gz` files automatically.
#
# The built-in `json` package has a `loads` function that converts a JSON string into a Python dictionary. We could call that once for each row of the file. [`ujson`](http://docs.micropython.org/en/latest/library/ujson.html) has the same interface as the built-in `json` package, but is *substantially* faster (at the cost of non-robust handling of malformed JSON). We will use that inside a list comprehension to get a list of dictionaries:

# %%
import ujson as json
import gzip

with gzip.open('yelp_train_academic_dataset_business.json.gz') as f:
    data = [json.loads(line) for line in f]

# %% [markdown]
# In scikit-learn, the labels to be predicted, in this case, the stars, are always kept in a separate data structure than the features. Let's get in this habit now, by creating a separate list of the ratings.

# %%
star_ratings = [row['stars'] for row in data]

# %%
data
# Out:
# [{'business_id': 'vcNAWiLM4dR7D2nwwJ7nCA',
#   'full_address': '4840 E Indian School Rd\nSte 101\nPhoenix, AZ 85018',
#   'hours': {'Tuesday': {'close': '17:00', 'open': '08:00'},
#    'Friday': {'close': '17:00', 'open': '08:00'},
#    'Monday': {'close': '17:00', 'open': '08:00'},
#    'Wednesday': {'close': '17:00', 'open': '08:00'},
#    'Thursday': {'close': '17:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Doctors', 'Health & Medical'],
#   'city': 'Phoenix',
#   'review_count': 7,
#   'name': 'Eric Goldberg, MD',
#   'neighborhoods': [],
#   'longitude': -111.983758,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.499313,
#   'attributes': {'By Appointment Only': True},
#   'type': 'business'},
#  {'business_id': 'JwUE5GmEO-sH1FuwJgKBlQ',
#   'full_address': '6162 US Highway 51\nDe Forest, WI 53532',
#   'hours': {},
#   'open': True,
#   'categories': ['Restaurants'],
#   'city': 'De Forest',
#   'review_count': 26,
#   'name': 'Pine Cone Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.335844,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.238893,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': False},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'uGykseHzyS5xAMWoN6YUqA',
#   'full_address': '505 W North St\nDe Forest, WI 53532',
#   'hours': {'Monday': {'close': '22:00', 'open': '06:00'},
#    'Tuesday': {'close': '22:00', 'open': '06:00'},
#    'Friday': {'close': '22:00', 'open': '06:00'},
#    'Wednesday': {'close': '22:00', 'open': '06:00'},
#    'Thursday': {'close': '22:00', 'open': '06:00'},
#    'Sunday': {'close': '21:00', 'open': '06:00'},
#    'Saturday': {'close': '22:00', 'open': '06:00'}},
#   'open': True,
#   'categories': ['American (Traditional)', 'Restaurants'],
#   'city': 'De Forest',
#   'review_count': 16,
#   'name': 'Deforest Family Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.353437,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.252267,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': True},
#    'Caters': False,
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'LRKJF43s9-3jG9Lgx4zODg',
#   'full_address': '4910 County Rd V\nDe Forest, WI 53532',
#   'hours': {'Monday': {'close': '22:00', 'open': '10:30'},
#    'Tuesday': {'close': '22:00', 'open': '10:30'},
#    'Friday': {'close': '22:00', 'open': '10:30'},
#    'Wednesday': {'close': '22:00', 'open': '10:30'},
#    'Thursday': {'close': '22:00', 'open': '10:30'},
#    'Sunday': {'close': '22:00', 'open': '10:30'},
#    'Saturday': {'close': '22:00', 'open': '10:30'}},
#   'open': True,
#   'categories': ['Food',
#    'Ice Cream & Frozen Yogurt',
#    'Fast Food',
#    'Restaurants'],
#   'city': 'De Forest',
#   'review_count': 7,
#   'name': "Culver's",
#   'neighborhoods': [],
#   'longitude': -89.374983,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.251045,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'free',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Attire': 'casual',
#    'Accepts Credit Cards': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'RgDg-k9S5YD_BaxMckifkg',
#   'full_address': '631 S Main St\nDe Forest, WI 53532',
#   'hours': {'Monday': {'close': '22:00', 'open': '11:00'},
#    'Tuesday': {'close': '22:00', 'open': '11:00'},
#    'Friday': {'close': '22:30', 'open': '11:00'},
#    'Wednesday': {'close': '22:00', 'open': '11:00'},
#    'Thursday': {'close': '22:00', 'open': '11:00'},
#    'Sunday': {'close': '21:00', 'open': '16:00'},
#    'Saturday': {'close': '22:30', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'De Forest',
#   'review_count': 3,
#   'name': 'Chang Jiang Chinese Kitchen',
#   'neighborhoods': [],
#   'longitude': -89.3437217,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.2408748,
#   'attributes': {'Take-out': True,
#    'Has TV': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual'},
#   'type': 'business'},
#  {'business_id': 'oLctHIA1AxmsgOuu4dM6Vw',
#   'full_address': '4156 County Rd B\nMc Farland, WI 53558',
#   'hours': {},
#   'open': False,
#   'categories': ['Television Stations', 'Mass Media'],
#   'city': 'Mc Farland',
#   'review_count': 10,
#   'name': 'Charter Communications',
#   'neighborhoods': [],
#   'longitude': -89.3229199,
#   'state': 'WI',
#   'stars': 1.5,
#   'latitude': 42.9685074,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'ZW2WeP2Hp20tq0RG1NFkoQ',
#   'full_address': '4709 Triangle St\nMc Farland, WI 53558',
#   'hours': {},
#   'open': True,
#   'categories': ['Home Services', 'Heating & Air Conditioning/HVAC'],
#   'city': 'Mc Farland',
#   'review_count': 4,
#   'name': 'Air Quality Systems',
#   'neighborhoods': [],
#   'longitude': -89.2985442,
#   'state': 'WI',
#   'stars': 2.0,
#   'latitude': 43.0303561,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': '95p9Xg358BezJyk1wqzzyg',
#   'full_address': '5114 Farwell St\nMc Farland, WI 53558',
#   'hours': {'Monday': {'close': '20:00', 'open': '09:00'},
#    'Tuesday': {'close': '20:00', 'open': '09:00'},
#    'Friday': {'close': '17:30', 'open': '09:00'},
#    'Wednesday': {'close': '20:00', 'open': '09:00'},
#    'Thursday': {'close': '20:00', 'open': '09:00'},
#    'Sunday': {'close': '15:00', 'open': '12:00'},
#    'Saturday': {'close': '17:30', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Libraries', 'Public Services & Government'],
#   'city': 'Mc Farland',
#   'review_count': 4,
#   'name': 'McFarland Public Library',
#   'neighborhoods': [],
#   'longitude': -89.294175,
#   'state': 'WI',
#   'stars': 2.5,
#   'latitude': 43.014093,
#   'attributes': {'Wi-Fi': 'free'},
#   'type': 'business'},
#  {'business_id': 'ZlhAvs_6ryi4_efZ1SpMbg',
#   'full_address': '4811 Larson Beach Rd\nMc Farland, WI 53558',
#   'hours': {'Monday': {'close': '18:00', 'open': '07:30'},
#    'Tuesday': {'close': '18:00', 'open': '07:30'},
#    'Friday': {'close': '18:00', 'open': '07:30'},
#    'Wednesday': {'close': '18:00', 'open': '07:30'},
#    'Thursday': {'close': '18:00', 'open': '07:30'},
#    'Saturday': {'close': '12:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Veterinarians', 'Pets'],
#   'city': 'Mc Farland',
#   'review_count': 3,
#   'name': 'Spartan Animal Hospital',
#   'neighborhoods': [],
#   'longitude': -89.299119,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.017124,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': '_wZTYYL7cutanzAnJUTGMA',
#   'full_address': '4506 Larson Beach Rd\nMc Farland, WI 53558',
#   'hours': {},
#   'open': True,
#   'categories': ['Bars',
#    'American (Traditional)',
#    'Nightlife',
#    'Lounges',
#    'Restaurants'],
#   'city': 'Mc Farland',
#   'review_count': 31,
#   'name': 'Beach House Restaurant & Lounge',
#   'neighborhoods': [],
#   'longitude': -89.303789,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.017701,
#   'attributes': {'Alcohol': 'full_bar',
#    'Noise Level': 'loud',
#    'Music': {},
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Good for Kids': True,
#    'Wheelchair Accessible': True,
#    'Good For Dancing': False,
#    'Delivery': False,
#    'Coat Check': False,
#    'Smoking': 'outdoor',
#    'Accepts Credit Cards': True,
#    'Take-out': True,
#    'Price Range': 2,
#    'Happy Hour': True,
#    'Outdoor Seating': True,
#    'Takes Reservations': True,
#    'Waiter Service': True,
#    'Wi-Fi': 'no',
#    'Caters': False,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'breakfast': False,
#     'brunch': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Good For Groups': True},
#   'type': 'business'},
#  {'business_id': 'XrzTVrJAjs0yYLvhFI9vkQ',
#   'full_address': '5508 Broadhead St\nMc Farland, WI 53558',
#   'hours': {},
#   'open': True,
#   'categories': ['Hotels & Travel',
#    'Bed & Breakfast',
#    'Event Planning & Services',
#    'Hotels'],
#   'city': 'Mc Farland',
#   'review_count': 9,
#   'name': 'Parsonage Bed & Breakfast the',
#   'neighborhoods': [],
#   'longitude': -89.285206,
#   'state': 'WI',
#   'stars': 5.0,
#   'latitude': 43.015931,
#   'attributes': {'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': '1tkeiIa-daD8LbM6mHm_9A',
#   'full_address': '4711 Farwell St\nMc Farland, WI 53558',
#   'hours': {'Monday': {'close': '02:00', 'open': '11:00'},
#    'Tuesday': {'close': '02:00', 'open': '11:00'},
#    'Friday': {'close': '02:30', 'open': '11:00'},
#    'Wednesday': {'close': '02:00', 'open': '11:00'},
#    'Thursday': {'close': '02:00', 'open': '11:00'},
#    'Sunday': {'close': '01:00', 'open': '08:00'},
#    'Saturday': {'close': '02:30', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Active Life', 'Bowling'],
#   'city': 'Mc Farland',
#   'review_count': 3,
#   'name': 'Spartan Bowl',
#   'neighborhoods': [],
#   'longitude': -89.3021641,
#   'state': 'WI',
#   'stars': 1.5,
#   'latitude': 43.0131557,
#   'attributes': {'Good for Kids': True},
#   'type': 'business'},
#  {'business_id': 'zOc8lbjViUZajbY7M0aUCQ',
#   'full_address': '5813 Main St\nMc Farland, WI 53558',
#   'hours': {'Tuesday': {'close': '22:00', 'open': '16:30'},
#    'Sunday': {'close': '20:00', 'open': '12:00'},
#    'Thursday': {'close': '22:00', 'open': '16:30'},
#    'Monday': {'close': '21:00', 'open': '16:30'},
#    'Wednesday': {'close': '22:00', 'open': '16:30'}},
#   'open': True,
#   'categories': ['Pizza', 'Restaurants'],
#   'city': 'Mc Farland',
#   'review_count': 4,
#   'name': 'Spartan Pizza',
#   'neighborhoods': [],
#   'longitude': -89.288567,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.014164,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Caters': False,
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': False,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'UgjVZTSOaYoEvws_lAP_Dw',
#   'full_address': '4850 Larson Beach Rd\nMc Farland, WI 53558',
#   'hours': {},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'Mc Farland',
#   'review_count': 8,
#   'name': 'Main Moon Chinese Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.2986278,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.0179387,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Has TV': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'HxPpZSY6Q1eARuiahhra6A',
#   'full_address': '6401 University Ave\nMiddleton, WI 53562',
#   'hours': {},
#   'open': False,
#   'categories': ['Event Planning & Services',
#    'Party & Event Planning',
#    'Caterers'],
#   'city': 'Middleton',
#   'review_count': 5,
#   'name': 'Crandalls Carryout & Catering',
#   'neighborhoods': [],
#   'longitude': -89.4918,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.093265,
#   'attributes': {'Take-out': True,
#    'Caters': True,
#    'Attire': 'casual',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': False,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'SKLw05kEIlZcpTD5pqma8Q',
#   'full_address': '2039 Allen Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '14:00', 'open': '11:00'},
#    'Tuesday': {'close': '14:00', 'open': '11:00'},
#    'Friday': {'close': '21:30', 'open': '16:00'},
#    'Wednesday': {'close': '21:30', 'open': '16:00'},
#    'Thursday': {'close': '21:30', 'open': '16:00'},
#    'Sunday': {'close': '21:00', 'open': '16:00'},
#    'Saturday': {'close': '21:00', 'open': '16:00'}},
#   'open': True,
#   'categories': ['Party & Event Planning',
#    'Asian Fusion',
#    'Event Planning & Services',
#    'Venues & Event Spaces',
#    'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 41,
#   'name': 'Imperial Garden Chinese Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.485169,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.090642,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'average',
#    'Takes Reservations': True,
#    'Has TV': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': '77ESrCo7hQ96VpCWWdvoxg',
#   'full_address': '6230 University Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '06:00'},
#    'Tuesday': {'close': '21:00', 'open': '06:00'},
#    'Friday': {'close': '21:00', 'open': '06:00'},
#    'Wednesday': {'close': '21:00', 'open': '06:00'},
#    'Thursday': {'close': '21:00', 'open': '06:00'},
#    'Sunday': {'close': '14:00', 'open': '08:00'},
#    'Saturday': {'close': '21:00', 'open': '06:00'}},
#   'open': False,
#   'categories': ['Mexican', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 17,
#   'name': 'Mi Cocina',
#   'neighborhoods': [],
#   'longitude': -89.4874867,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.0910607,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'average',
#    'Good for Kids': True,
#    'Takes Reservations': False,
#    'Has TV': True,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good For Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': '368m5-RtrrYWf4hPM_bMlg',
#   'full_address': '8312 Forsythia St\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '09:00'},
#    'Tuesday': {'close': '21:00', 'open': '09:00'},
#    'Friday': {'close': '21:00', 'open': '09:00'},
#    'Wednesday': {'close': '21:00', 'open': '09:00'},
#    'Thursday': {'close': '21:00', 'open': '09:00'},
#    'Sunday': {'close': '21:00', 'open': '12:00'},
#    'Saturday': {'close': '21:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Active Life', 'Arts & Entertainment', 'Stadiums & Arenas'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': 'Keva Sports Center',
#   'neighborhoods': [],
#   'longitude': -89.5264281,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.1101571,
#   'attributes': {'Good for Kids': True},
#   'type': 'business'},
#  {'business_id': 'YjoSdr8uJslIebsQP6c18w',
#   'full_address': '8402 Old Sauk Rd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Pet Services', 'Pets'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': 'Wild Birds Unlimited',
#   'neighborhoods': [],
#   'longitude': -89.527273,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.077415,
#   'attributes': {'Accepts Credit Cards': True, 'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'rKNtd_M2kWDW8sQKYzetKA',
#   'full_address': '7790 Elmwood Ave\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Hotels & Travel',
#    'Event Planning & Services',
#    'Venues & Event Spaces',
#    'Hotels'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': 'Staybridge Suites Extended Stay Hotel Middleton/Madison-West',
#   'neighborhoods': [],
#   'longitude': -89.516038,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.096271,
#   'attributes': {'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Price Range': 3},
#   'type': 'business'},
#  {'business_id': 'x7xS2DJvu8klyNzcpN8QHg',
#   'full_address': '2529 Allen Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '00:00', 'open': '00:00'},
#    'Tuesday': {'close': '00:00', 'open': '00:00'},
#    'Friday': {'close': '00:00', 'open': '00:00'},
#    'Wednesday': {'close': '00:00', 'open': '00:00'},
#    'Thursday': {'close': '00:00', 'open': '00:00'},
#    'Sunday': {'close': '00:00', 'open': '00:00'},
#    'Saturday': {'close': '00:00', 'open': '00:00'}},
#   'open': True,
#   'categories': ['Pilates',
#    'Yoga',
#    'Weight Loss Centers',
#    'Health & Medical',
#    'Fitness & Instruction',
#    'Active Life'],
#   'city': 'Middleton',
#   'review_count': 5,
#   'name': 'Harbor Athletic Club',
#   'neighborhoods': [],
#   'longitude': -89.4860822,
#   'state': 'WI',
#   'stars': 5.0,
#   'latitude': 43.1030719,
#   'attributes': {'By Appointment Only': False, 'Good for Kids': True},
#   'type': 'business'},
#  {'business_id': 'KTqNU4plO23583DYAMGXYg',
#   'full_address': '2411 Allen Blvd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Sandwiches', 'Pizza', 'Chicken Wings', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': "Domino's Pizza",
#   'neighborhoods': [],
#   'longitude': -89.4862189,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.1003841,
#   'attributes': {'Take-out': True,
#    'Takes Reservations': False,
#    'Delivery': True,
#    'Outdoor Seating': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False}},
#   'type': 'business'},
#  {'business_id': 'cgCqxPhadIAlsqnD1MoWuQ',
#   'full_address': '1661 Deming Way\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '09:30'},
#    'Tuesday': {'close': '21:00', 'open': '09:30'},
#    'Friday': {'close': '21:00', 'open': '09:30'},
#    'Wednesday': {'close': '21:00', 'open': '09:30'},
#    'Thursday': {'close': '21:00', 'open': '09:30'},
#    'Sunday': {'close': '18:00', 'open': '11:00'},
#    'Saturday': {'close': '21:00', 'open': '09:30'}},
#   'open': True,
#   'categories': ['Shopping',
#    'Arts & Crafts',
#    'Event Planning & Services',
#    'Cards & Stationery',
#    'Art Supplies',
#    'Flowers & Gifts'],
#   'city': 'Middleton',
#   'review_count': 4,
#   'name': 'Archivers',
#   'neighborhoods': [],
#   'longitude': -89.5235246,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.0954975,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Price Range': 3},
#   'type': 'business'},
#  {'business_id': 'YDUB7-NgjKEFn8CERLoKXQ',
#   'full_address': '1700 Deming Way\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '09:00'},
#    'Tuesday': {'close': '21:00', 'open': '09:00'},
#    'Friday': {'close': '21:00', 'open': '09:00'},
#    'Wednesday': {'close': '21:00', 'open': '09:00'},
#    'Thursday': {'close': '21:00', 'open': '09:00'},
#    'Sunday': {'close': '19:00', 'open': '10:00'},
#    'Saturday': {'close': '21:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Arts & Crafts',
#    'Shopping',
#    'Knitting Supplies',
#    'Hobby Shops'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': 'Michaels',
#   'neighborhoods': [],
#   'longitude': -89.5277025,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.0929029,
#   'attributes': {'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'x7pStpT09Tdc8d7oRU0Tmw',
#   'full_address': '1620 Deming Way\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '20:00', 'open': '10:00'},
#    'Tuesday': {'close': '20:00', 'open': '10:00'},
#    'Friday': {'close': '20:00', 'open': '10:00'},
#    'Wednesday': {'close': '20:00', 'open': '10:00'},
#    'Thursday': {'close': '20:00', 'open': '10:00'},
#    'Sunday': {'close': '17:00', 'open': '12:00'},
#    'Saturday': {'close': '20:00', 'open': '10:00'}},
#   'open': True,
#   'categories': ["Women's Clothing",
#    'Shopping Centers',
#    'Fashion',
#    'Shopping'],
#   'city': 'Middleton',
#   'review_count': 7,
#   'name': 'Greenway Station Shopping Center',
#   'neighborhoods': [],
#   'longitude': -89.52845,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.091816,
#   'attributes': {'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': '1-EIdeHewfEVcpoZm38N8A',
#   'full_address': '1901 Cayuga St\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '06:00'},
#    'Tuesday': {'close': '21:00', 'open': '06:00'},
#    'Friday': {'close': '21:00', 'open': '06:00'},
#    'Wednesday': {'close': '21:00', 'open': '06:00'},
#    'Thursday': {'close': '21:00', 'open': '06:00'},
#    'Sunday': {'close': '19:00', 'open': '07:00'},
#    'Saturday': {'close': '21:00', 'open': '06:30'}},
#   'open': True,
#   'categories': ['Food', 'Beer, Wine & Spirits', 'Coffee & Tea'],
#   'city': 'Middleton',
#   'review_count': 22,
#   'name': 'Barriques Wine & Spirits',
#   'neighborhoods': [],
#   'longitude': -89.513737,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.096359,
#   'attributes': {'Wi-Fi': 'free',
#    'Price Range': 1,
#    'Outdoor Seating': True,
#    'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True},
#   'type': 'business'},
#  {'business_id': 'ShEYKerTwb2LSORE5o_s7A',
#   'full_address': '6720 Frank Lloyd Wright Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '15:00', 'open': '07:00'},
#    'Tuesday': {'close': '15:00', 'open': '07:00'},
#    'Friday': {'close': '15:00', 'open': '07:00'},
#    'Wednesday': {'close': '15:00', 'open': '07:00'},
#    'Thursday': {'close': '15:00', 'open': '07:00'},
#    'Sunday': {'close': '14:00', 'open': '07:00'},
#    'Saturday': {'close': '14:00', 'open': '07:00'}},
#   'open': True,
#   'categories': ['Bakeries',
#    'Food',
#    'Breakfast & Brunch',
#    'Coffee & Tea',
#    'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 38,
#   'name': 'Prairie Cafe & Bakery',
#   'neighborhoods': [],
#   'longitude': -89.496995,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.107227,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'free',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': True},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Has TV': False,
#    'Delivery': False,
#    'Dogs Allowed': False,
#    'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': False,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'HaBkx5PwvbBpQ2iNCgHnVQ',
#   'full_address': '2401 Parmenter St\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '11:00', 'open': '07:00'},
#    'Tuesday': {'close': '11:00', 'open': '07:00'},
#    'Friday': {'close': '11:00', 'open': '07:00'},
#    'Wednesday': {'close': '11:00', 'open': '07:00'},
#    'Thursday': {'close': '13:00', 'open': '11:00'},
#    'Sunday': {'close': '11:00', 'open': '08:00'},
#    'Saturday': {'close': '11:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Bars', 'American (New)', 'Nightlife', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 11,
#   'name': "Paul's Neighborhood Bar",
#   'neighborhoods': [],
#   'longitude': -89.5111616,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.1014598,
#   'attributes': {'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'average',
#    'Attire': 'casual',
#    'Happy Hour': True,
#    'Music': {'video': False, 'live': False, 'dj': False, 'jukebox': True},
#    'Outdoor Seating': True,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Alcohol': 'full_bar',
#    'Smoking': 'no',
#    'Takes Reservations': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': False,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'KW6HejC-67KSL9J8Cz1dSw',
#   'full_address': '8414 Old Sauk Rd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '21:00', 'open': '11:00'},
#    'Tuesday': {'close': '21:00', 'open': '11:00'},
#    'Friday': {'close': '21:00', 'open': '11:00'},
#    'Wednesday': {'close': '21:00', 'open': '11:00'},
#    'Thursday': {'close': '21:00', 'open': '11:00'},
#    'Sunday': {'close': '21:00', 'open': '11:00'},
#    'Saturday': {'close': '21:00', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 28,
#   'name': "Chin's Asia Fresh",
#   'neighborhoods': [],
#   'longitude': -89.528480180844,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.075345267736,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Has TV': False,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'wl-7A4jC0f27MOEmW-XTbQ',
#   'full_address': '2608 Allen Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '22:00', 'open': '11:00'},
#    'Tuesday': {'close': '22:00', 'open': '11:00'},
#    'Friday': {'close': '23:00', 'open': '11:00'},
#    'Wednesday': {'close': '22:00', 'open': '11:00'},
#    'Thursday': {'close': '22:00', 'open': '11:00'},
#    'Sunday': {'close': '22:00', 'open': '12:00'},
#    'Saturday': {'close': '23:00', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': 'Grand China Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.4864907,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.1036633,
#   'attributes': {'Take-out': True,
#    'Takes Reservations': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Attire': 'casual',
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'NGj-_5pkHc_DbH5bKUH2Xw',
#   'full_address': '2313 Parmenter St\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Pet Services', 'Pet Boarding/Pet Sitting', 'Pets'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': "Lori's Pet-Agree Salon Llc",
#   'neighborhoods': [],
#   'longitude': -89.511068,
#   'state': 'WI',
#   'stars': 5.0,
#   'latitude': 43.100808,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'suQyHycqv8nA7EualcUB3g',
#   'full_address': '8302 Greenway Blvd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Diners', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 5,
#   'name': 'Dennys',
#   'neighborhoods': [],
#   'longitude': -89.5241674,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.0905631,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': False},
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Has TV': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': '3jpKGDkFrCHpjEYVEgcG0A',
#   'full_address': '8310 Greenway Blvd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Food', 'Coffee & Tea'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': 'Starbucks',
#   'neighborhoods': [],
#   'longitude': -89.5256818,
#   'state': 'WI',
#   'stars': 3.0,
#   'latitude': 43.0904559,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Outdoor Seating': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'AYoLKzRFajucKnjIFxc__A',
#   'full_address': '1650 Deming Way\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Food', 'Ice Cream & Frozen Yogurt'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': 'Cold Stone Creamery',
#   'neighborhoods': [],
#   'longitude': -89.5235823,
#   'state': 'WI',
#   'stars': 2.5,
#   'latitude': 43.0954855,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Takes Reservations': False,
#    'Has TV': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 4},
#   'type': 'business'},
#  {'business_id': 'c5awCF5eu0ZkxUf_i94uPA',
#   'full_address': '2611 Branch St\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Nightlife'],
#   'city': 'Middleton',
#   'review_count': 16,
#   'name': 'Bristled Boar Saloon & Grill',
#   'neighborhoods': [],
#   'longitude': -89.491807,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.103427,
#   'attributes': {'Price Range': 1,
#    'Alcohol': 'full_bar',
#    'Good For Dancing': True,
#    'Noise Level': 'average',
#    'Coat Check': False,
#    'Has TV': True,
#    'Happy Hour': True,
#    'Music': {'video': False, 'live': False, 'dj': False, 'jukebox': True},
#    'Outdoor Seating': True,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Smoking': 'outdoor',
#    'Accepts Credit Cards': True,
#    'Good For Groups': True,
#    'Wheelchair Accessible': True},
#   'type': 'business'},
#  {'business_id': 'uga5g16PncJOtY7Sc3A05w',
#   'full_address': '8308 Greenway Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '23:00', 'open': '05:00'},
#    'Tuesday': {'close': '23:00', 'open': '05:00'},
#    'Friday': {'close': '00:00', 'open': '05:00'},
#    'Wednesday': {'close': '23:00', 'open': '05:00'},
#    'Thursday': {'close': '23:00', 'open': '05:00'},
#    'Sunday': {'close': '23:00', 'open': '06:00'},
#    'Saturday': {'close': '00:00', 'open': '06:00'}},
#   'open': True,
#   'categories': ['Burgers', 'Fast Food', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 6,
#   'name': "McDonald's",
#   'neighborhoods': [],
#   'longitude': -89.5250779,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.090653,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'free',
#    'Alcohol': 'none',
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Has TV': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Attire': 'casual',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': '9874O-3GjXPotxYKNNAz5Q',
#   'full_address': '1009 N Gammon Rd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '18:00', 'open': '08:00'},
#    'Tuesday': {'close': '18:00', 'open': '08:00'},
#    'Friday': {'close': '18:00', 'open': '08:00'},
#    'Wednesday': {'close': '18:00', 'open': '08:00'},
#    'Thursday': {'close': '18:00', 'open': '08:00'},
#    'Saturday': {'close': '12:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Veterinarians', 'Pets'],
#   'city': 'Middleton',
#   'review_count': 5,
#   'name': 'All Pets Veterinary Clinic',
#   'neighborhoods': [],
#   'longitude': -89.5022518,
#   'state': 'WI',
#   'stars': 5.0,
#   'latitude': 43.082611,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'naqkXvhoqljvA7kuo15gEw',
#   'full_address': '8212 Greenway Blvd\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '00:00', 'open': '00:00'},
#    'Tuesday': {'close': '00:00', 'open': '00:00'},
#    'Friday': {'close': '00:00', 'open': '00:00'},
#    'Wednesday': {'close': '00:00', 'open': '00:00'},
#    'Thursday': {'close': '00:00', 'open': '00:00'},
#    'Sunday': {'close': '00:00', 'open': '00:00'},
#    'Saturday': {'close': '00:00', 'open': '00:00'}},
#   'open': True,
#   'categories': ['Hotels & Travel', 'Event Planning & Services', 'Hotels'],
#   'city': 'Middleton',
#   'review_count': 8,
#   'name': 'Fairfield Inn & Suites Madison West',
#   'neighborhoods': [],
#   'longitude': -89.5233883,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.0901268,
#   'attributes': {'Dogs Allowed': False,
#    'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'xbJ9tdGbcVJIUkNgHSCwZQ',
#   'full_address': '1914 Aurora St\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Bars', 'Nightlife', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 10,
#   'name': 'Hody Bar & Grill',
#   'neighborhoods': [],
#   'longitude': -89.5128222,
#   'state': 'WI',
#   'stars': 2.5,
#   'latitude': 43.095696,
#   'attributes': {'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Good For Dancing': True,
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Has TV': True,
#    'Smoking': 'no',
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': False,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'koRLvzIl-4fCybOIdk56jA',
#   'full_address': '7464 Hubbard Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '23:00', 'open': '17:00'},
#    'Tuesday': {'close': '23:00', 'open': '17:00'},
#    'Friday': {'close': '23:00', 'open': '17:00'},
#    'Wednesday': {'close': '23:00', 'open': '17:00'},
#    'Thursday': {'close': '23:00', 'open': '17:00'},
#    'Saturday': {'close': '23:00', 'open': '17:00'}},
#   'open': True,
#   'categories': ['Cajun/Creole', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 56,
#   'name': "Louisianne's Etc",
#   'neighborhoods': [],
#   'longitude': -89.5110574,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.0955526,
#   'attributes': {'Take-out': False,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'average',
#    'Good for Kids': False,
#    'Takes Reservations': True,
#    'Has TV': False,
#    'Delivery': False,
#    'Ambience': {'romantic': True,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Wheelchair Accessible': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good For Kids': False,
#    'Good For Groups': True,
#    'Price Range': 3},
#   'type': 'business'},
#  {'business_id': 'ckLRf3lYn9DxmNxd-mu2yA',
#   'full_address': '1313 John Q Hammons Dr\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '17:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Hotels & Travel', 'Event Planning & Services', 'Hotels'],
#   'city': 'Middleton',
#   'review_count': 35,
#   'name': 'Marriott-Madison West',
#   'neighborhoods': [],
#   'longitude': -89.523172,
#   'state': 'WI',
#   'stars': 2.5,
#   'latitude': 43.087887,
#   'attributes': {'Take-out': False,
#    'Wi-Fi': 'paid',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Noise Level': 'very_loud',
#    'Takes Reservations': True,
#    'Has TV': True,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'Bznf9AaGgdsLI01H_ifrUA',
#   'full_address': '7625 Lisa Ln\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
#   'categories': ['Active Life', 'Amateur Sports Teams'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': 'Bowling Green Rec Center',
#   'neighborhoods': [],
#   'longitude': -89.511857,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.1083799,
#   'attributes': {'Good for Kids': True},
#   'type': 'business'},
#  {'business_id': 'YaaQx4qt1f36iFT4TWivAw',
#   'full_address': '7610 Donna Dr\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '17:30', 'open': '07:00'},
#    'Tuesday': {'close': '17:30', 'open': '07:00'},
#    'Friday': {'close': '17:30', 'open': '07:00'},
#    'Wednesday': {'close': '17:30', 'open': '07:00'},
#    'Thursday': {'close': '17:30', 'open': '07:00'},
#    'Saturday': {'close': '17:00', 'open': '07:30'}},
#   'open': True,
#   'categories': ['Bakeries', 'Food'],
#   'city': 'Middleton',
#   'review_count': 14,
#   'name': "Clasen's European Bakery",
#   'neighborhoods': [],
#   'longitude': -89.51178,
#   'state': 'WI',
#   'stars': 3.5,
#   'latitude': 43.1060972,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'MBQc_jlZ3nlMOZy7SUM_5Q',
#   'full_address': '1801 Deming Way\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '00:00', 'open': '00:00'},
#    'Tuesday': {'close': '00:00', 'open': '00:00'},
#    'Friday': {'close': '00:00', 'open': '00:00'},
#    'Wednesday': {'close': '00:00', 'open': '00:00'},
#    'Thursday': {'close': '00:00', 'open': '00:00'},
#    'Sunday': {'close': '00:00', 'open': '00:00'},
#    'Saturday': {'close': '00:00', 'open': '00:00'}},
#   'open': True,
#   'categories': ['Hotels & Travel', 'Event Planning & Services', 'Hotels'],
#   'city': 'Middleton',
#   'review_count': 12,
#   'name': 'Hilton Garden Inn Madison West/Middleton',
#   'neighborhoods': [],
#   'longitude': -89.525484,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.092882,
#   'attributes': {'Dogs Allowed': False,
#    'Accepts Credit Cards': True,
#    'Wi-Fi': 'free',
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'cruBFtsFaBuhX_I72uU8pA',
#   'full_address': '6615 University Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '22:00', 'open': '10:00'},
#    'Tuesday': {'close': '22:00', 'open': '10:00'},
#    'Friday': {'close': '22:00', 'open': '10:00'},
#    'Wednesday': {'close': '22:00', 'open': '10:00'},
#    'Thursday': {'close': '22:00', 'open': '10:00'},
#    'Sunday': {'close': '22:00', 'open': '10:00'},
#    'Saturday': {'close': '22:00', 'open': '10:00'}},
#   'open': True,
#   'categories': ['Pizza', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 3,
#   'name': "Papa John's Pizza",
#   'neighborhoods': [],
#   'longitude': -89.4949208,
#   'state': 'WI',
#   'stars': 1.5,
#   'latitude': 43.0955472,
#   'attributes': {'Take-out': True,
#    'Alcohol': 'none',
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Price Range': 2,
#    'Good For Groups': True,
#    'Wheelchair Accessible': True},
#   'type': 'business'},
#  {'business_id': 'X47o6R2rWiqGqvBtC7VS3Q',
#   'full_address': '2227 Parmenter St\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '14:00', 'open': '06:30'},
#    'Tuesday': {'close': '14:00', 'open': '06:30'},
#    'Friday': {'close': '13:30', 'open': '06:30'},
#    'Wednesday': {'close': '14:00', 'open': '06:30'},
#    'Thursday': {'close': '14:00', 'open': '06:30'},
#    'Sunday': {'close': '12:00', 'open': '07:00'},
#    'Saturday': {'close': '12:00', 'open': '06:30'}},
#   'open': True,
#   'categories': ['Breakfast & Brunch', 'Restaurants'],
#   'city': 'Middleton',
#   'review_count': 19,
#   'name': 'Three Sisters Old Town Inn',
#   'neighborhoods': [],
#   'longitude': -89.511243,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.0999335,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': True},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Parking': {'garage': False,
#     'street': True,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Has TV': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': True,
#    'Accepts Credit Cards': False,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': '_tnYCShXuDlXjNVNctTkCA',
#   'full_address': '6323 University Ave\nMiddleton, WI 53562',
#   'hours': {'Monday': {'close': '17:00', 'open': '08:00'},
#    'Tuesday': {'close': '17:00', 'open': '08:00'},
#    'Friday': {'close': '17:00', 'open': '08:00'},
#    'Wednesday': {'close': '17:00', 'open': '08:00'},
#    'Thursday': {'close': '17:00', 'open': '08:00'},
#    'Saturday': {'close': '14:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Barbers', 'Beauty & Spas'],
#   'city': 'Middleton',
#   'review_count': 11,
#   'name': "Dick & Arnie's Barber Shop",
#   'neighborhoods': [],
#   'longitude': -89.4904366,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.0926846,
#   'attributes': {'By Appointment Only': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': False,
#    'Wheelchair Accessible': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'elBgDynz6UPoSqQgxiggJw',
#   'full_address': '3201 Glacier Ridge Rd\nMiddleton, WI 53562',
#   'hours': {},
#   'open': True,
# ...
#    'Saturday': {'close': '17:30', 'open': '08:30'}},
#   'open': False,
#   'categories': ['Car Wash', 'Automotive'],
#   'city': 'Phoenix',
#   'review_count': 16,
#   'name': 'Arcadia Car Wash',
#   'neighborhoods': [],
#   'longitude': -111.9867688,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.4948739,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'VxnV1uMZURUQMNUaPdB8QA',
#   'full_address': '4515 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '23:00', 'open': '08:00'},
#    'Tuesday': {'close': '23:00', 'open': '08:00'},
#    'Friday': {'close': '23:00', 'open': '08:00'},
#    'Wednesday': {'close': '23:00', 'open': '08:00'},
#    'Thursday': {'close': '23:00', 'open': '08:00'},
#    'Sunday': {'close': '22:00', 'open': '08:00'},
#    'Saturday': {'close': '23:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Department Stores', 'Fashion', 'Shopping', 'Drugstores'],
#   'city': 'Phoenix',
#   'review_count': 36,
#   'name': 'Target',
#   'neighborhoods': [],
#   'longitude': -111.9850859,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.4801135,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'JksZiHb_Vj1tYRTpuTg-uQ',
#   'full_address': '4519 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '21:00', 'open': '08:00'},
#    'Tuesday': {'close': '21:00', 'open': '08:00'},
#    'Friday': {'close': '21:00', 'open': '08:00'},
#    'Wednesday': {'close': '21:00', 'open': '08:00'},
#    'Thursday': {'close': '21:00', 'open': '08:00'},
#    'Sunday': {'close': '18:00', 'open': '10:00'},
#    'Saturday': {'close': '19:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Shopping', 'Office Equipment'],
#   'city': 'Phoenix',
#   'review_count': 7,
#   'name': 'Office Max',
#   'neighborhoods': [],
#   'longitude': -111.9854985,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.4800765,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'SDwYQ6eSu1htn8vHWv128g',
#   'full_address': '3939 E Campbell Ave\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '23:00', 'open': '11:00'},
#    'Tuesday': {'close': '23:00', 'open': '11:00'},
#    'Friday': {'close': '00:00', 'open': '11:00'},
#    'Wednesday': {'close': '23:00', 'open': '11:00'},
#    'Thursday': {'close': '23:00', 'open': '11:00'},
#    'Sunday': {'close': '22:00', 'open': '09:00'},
#    'Saturday': {'close': '00:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Wine Bars', 'Bars', 'Restaurants', 'Nightlife', 'Italian'],
#   'city': 'Phoenix',
#   'review_count': 921,
#   'name': 'Postino Arcadia',
#   'neighborhoods': [],
#   'longitude': -111.996292,
#   'state': 'AZ',
#   'stars': 4.5,
#   'latitude': 33.502191,
#   'attributes': {'Alcohol': 'beer_and_wine',
#    'Open 24 Hours': False,
#    'Noise Level': 'average',
#    'Music': {'dj': False,
#     'background_music': True,
#     'jukebox': False,
#     'live': False,
#     'video': False,
#     'karaoke': False},
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': True,
#     'upscale': False,
#     'casual': False},
#    'Good for Kids': False,
#    'Wheelchair Accessible': True,
#    'Delivery': False,
#    'Good For Dancing': False,
#    'BYOB': False,
#    'Coat Check': False,
#    'Smoking': 'outdoor',
#    'Accepts Credit Cards': True,
#    'BYOB/Corkage': 'no',
#    'Take-out': True,
#    'Price Range': 2,
#    'Corkage': False,
#    'Happy Hour': True,
#    'Outdoor Seating': True,
#    'Takes Reservations': True,
#    'Waiter Service': True,
#    'Wi-Fi': 'no',
#    'Caters': True,
#    'Dietary Restrictions': {'dairy-free': False,
#     'gluten-free': False,
#     'vegan': True,
#     'kosher': False,
#     'halal': False,
#     'soy-free': False,
#     'vegetarian': True},
#    'Order at Counter': False,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': True},
#    'Has TV': False,
#    'Good For Kids': False,
#    'Good For Groups': True},
#   'type': 'business'},
#  {'business_id': '7UTlEVHU5v2xBLdkGghyzQ',
#   'full_address': '3222 E Indian School Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': False,
#   'categories': ['Mexican', 'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 21,
#   'name': "Chuy's Mesquite Broiler",
#   'neighborhoods': [],
#   'longitude': -112.0119403,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.4953259,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Takes Reservations': False,
#    'BYOB/Corkage': 'no',
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': '5WQhLNpG6xZryVCla4gMRA',
#   'full_address': '4505 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '00:00', 'open': '06:00'},
#    'Tuesday': {'close': '00:00', 'open': '06:00'},
#    'Friday': {'close': '00:00', 'open': '06:00'},
#    'Wednesday': {'close': '00:00', 'open': '06:00'},
#    'Thursday': {'close': '00:00', 'open': '06:00'},
#    'Sunday': {'close': '00:00', 'open': '06:00'},
#    'Saturday': {'close': '00:00', 'open': '06:00'}},
#   'open': True,
#   'categories': ['Grocery',
#    'American (Traditional)',
#    'Shopping',
#    'Drugstores',
#    'Food',
#    'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 26,
#   'name': "Fry's Food Store",
#   'neighborhoods': [],
#   'longitude': -111.984771,
#   'state': 'AZ',
#   'stars': 2.5,
#   'latitude': 33.479131,
#   'attributes': {'Take-out': False,
#    'Wi-Fi': 'free',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'brunch': False,
#     'breakfast': False},
#    'Caters': True,
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Has TV': True,
#    'BYOB/Corkage': 'yes_corkage',
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Corkage': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'r-EVE9HYaJoaaK82Z7o3OQ',
#   'full_address': '5130 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': True,
#   'categories': ['Pet Groomers', 'Pet Services', 'Pets'],
#   'city': 'Phoenix',
#   'review_count': 5,
#   'name': 'Ingleside Grooming',
#   'neighborhoods': [],
#   'longitude': -111.9702112,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.4801284,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'yJr24Yy1K6bt2G9fX3_zPA',
#   'full_address': '4225 E Camelback Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '21:30', 'open': '11:00'},
#    'Tuesday': {'close': '21:30', 'open': '11:00'},
#    'Friday': {'close': '22:00', 'open': '11:00'},
#    'Wednesday': {'close': '21:30', 'open': '11:00'},
#    'Thursday': {'close': '21:30', 'open': '11:00'},
#    'Sunday': {'close': '21:00', 'open': '16:00'},
#    'Saturday': {'close': '22:00', 'open': '11:00'}},
#   'open': False,
#   'categories': ['Cuban', 'Caribbean', 'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 188,
#   'name': 'Havana Cafe',
#   'neighborhoods': [],
#   'longitude': -111.9885861,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.5092093,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'no',
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'brunch': False,
#     'breakfast': False},
#    'Caters': True,
#    'Noise Level': 'average',
#    'Good for Kids': False,
#    'Takes Reservations': True,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Has TV': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Order at Counter': False,
#    'Wheelchair Accessible': True,
#    'Outdoor Seating': True,
#    'Attire': 'casual',
#    'Alcohol': 'full_bar',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good For Kids': False,
#    'Good For Groups': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'Qj2h9JA59E_J-ogfdjx7Lg',
#   'full_address': '3623 E Indian School Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': True,
#   'categories': [],
#   'city': 'Phoenix',
#   'review_count': 4,
#   'name': 'Famous Wings',
#   'neighborhoods': [],
#   'longitude': -112.0031664,
#   'state': 'AZ',
#   'stars': 2.5,
#   'latitude': 33.495169,
#   'attributes': {},
#   'type': 'business'},
#  {'business_id': 'wdEnI9WTLHiqSCH1RdJ40w',
#   'full_address': '4732 E Thomas Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': True,
#   'categories': ['Mexican', 'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 16,
#   'name': 'Los Armandos',
#   'neighborhoods': [],
#   'longitude': -111.978627,
#   'state': 'AZ',
#   'stars': 3.0,
#   'latitude': 33.480391,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': False},
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'qz4ZOcv-840UjfCEYI4qZg',
#   'full_address': '4829 E Indian School Rd\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '00:00', 'open': '15:30'},
#    'Tuesday': {'close': '00:00', 'open': '15:30'},
#    'Friday': {'close': '02:00', 'open': '15:30'},
#    'Wednesday': {'close': '00:00', 'open': '15:30'},
#    'Thursday': {'close': '00:00', 'open': '15:30'},
#    'Sunday': {'close': '17:30', 'open': '11:00'},
#    'Saturday': {'close': '02:00', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Burgers',
#    'Bars',
#    'American (Traditional)',
#    'Nightlife',
#    'Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 62,
#   'name': "Jt's Bar & Grill",
#   'neighborhoods': [],
#   'longitude': -111.976613,
#   'state': 'AZ',
#   'stars': 4.0,
#   'latitude': 33.494204,
#   'attributes': {'Drive-Thru': False,
#    'Alcohol': 'full_bar',
#    'Noise Level': 'average',
#    'Music': {'dj': False,
#     'background_music': False,
#     'jukebox': True,
#     'live': False,
#     'video': False,
#     'karaoke': False},
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': True,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Good for Kids': False,
#    'Wheelchair Accessible': True,
#    'Good For Dancing': False,
#    'Delivery': False,
#    'Coat Check': False,
#    'Smoking': 'outdoor',
#    'Accepts Credit Cards': True,
#    'BYOB/Corkage': 'no',
#    'Take-out': True,
#    'Price Range': 1,
#    'Happy Hour': False,
#    'Outdoor Seating': True,
#    'Takes Reservations': False,
#    'Waiter Service': True,
#    'Wi-Fi': 'free',
#    'Caters': False,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': True,
#     'breakfast': False,
#     'brunch': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Good For Groups': False},
#   'type': 'business'},
#  {'business_id': '015GCpe-tMj1En4NORROzA',
#   'full_address': '4801 E Indian School Rd\nSte 6\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '19:00', 'open': '07:00'},
#    'Tuesday': {'close': '19:00', 'open': '07:00'},
#    'Friday': {'close': '19:00', 'open': '07:00'},
#    'Wednesday': {'close': '19:00', 'open': '07:00'},
#    'Thursday': {'close': '19:00', 'open': '07:00'},
#    'Saturday': {'close': '18:00', 'open': '09:00'}},
#   'open': True,
#   'categories': ['Local Services', 'Dry Cleaning & Laundry'],
#   'city': 'Phoenix',
#   'review_count': 14,
#   'name': 'Elite Cleaners',
#   'neighborhoods': [],
#   'longitude': -111.977756,
#   'state': 'AZ',
#   'stars': 4.5,
#   'latitude': 33.49413,
#   'attributes': {'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wi-Fi': 'no',
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'AJONCMi8dnGWAkD-86FK5A',
#   'full_address': '4280 E Indian School Rd\nSte 107\nPhoenix, AZ 85018',
#   'hours': {'Monday': {'close': '18:00', 'open': '09:00'},
#    'Tuesday': {'close': '18:00', 'open': '09:00'},
#    'Friday': {'close': '18:00', 'open': '09:00'},
#    'Wednesday': {'close': '18:00', 'open': '09:00'},
#    'Thursday': {'close': '18:00', 'open': '09:00'},
#    'Sunday': {'close': '17:00', 'open': '11:00'},
#    'Saturday': {'close': '17:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Shopping',
#    'Optometrists',
#    'Health & Medical',
#    'Eyewear & Opticians'],
#   'city': 'Phoenix',
#   'review_count': 11,
#   'name': 'Nationwide Vision Centers',
#   'neighborhoods': [],
#   'longitude': -111.9891177,
#   'state': 'AZ',
#   'stars': 2.5,
#   'latitude': 33.495074,
#   'attributes': {'By Appointment Only': True,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': False,
#     'valet': False},
#    'Accepts Credit Cards': True,
#    'Wheelchair Accessible': True,
#    'Price Range': 2},
#   'type': 'business'},
#  {'business_id': 'FRDZ59oRvUSs4gf-itOCBg',
#   'full_address': '4343 E Camelback Rd\nPhoenix, AZ 85018',
#   'hours': {},
#   'open': True,
#   'categories': ['Restaurants'],
#   'city': 'Phoenix',
#   'review_count': 3,
#   'name': 'Jack in the Box',
#   'neighborhoods': [],
#   'longitude': -111.9875851,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.5091326,
#   'attributes': {'Take-out': True,
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'classy': False,
#     'hipster': False,
#     'divey': False,
#     'touristy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Waiter Service': False,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  ...]

# %% [markdown]
# # Questions

# %% [markdown]
# ## Question 1: city_avg

# %% [markdown]
# The venues belong to different cities.  You can imagine that the ratings in some cities are probably higher than others.  We wish to build an estimator to make a prediction based on this, #### but first we need to work out the average rating for each city.  For this problem, create a list of tuples (city name, star rating), one for each city in the data set. There are many ways to do this; please feel free to experiment on your own.  If you get stuck, the steps below attempt to guide you through the process.
#
# A simple approach is to go through all of the dictionaries in our array, calculating the sum of the star ratings and the number of venues for each city. At the end, we can just divide the stars by the count to get the average. We could create a separate sum and count variable for each city, but that will get tedious quickly. A better approach is to create a dictionary for each. The key will be the city name, and the value the running sum or running count.
#
# One slight annoyance of this approach is that we will have to test whether a key exists in the dictionary before adding to the running tally.  The `collections` module's `defaultdict` class works around this by providing default values for keys that haven't been used. Thus, if we do

# %%
from collections import defaultdict

star_sum = defaultdict(int)
count = defaultdict(int)

# %% [markdown]
# we can increment any key of `star_sum` or `count` without first worrying whether the key exists. We need to go through the `data` and `star_ratings` list together, which we can do with the `zip` function.

# %%
for row, stars in zip(data, star_ratings):
    # increment the running sum in star_sum
    star_sum[row['city']]=star_sum.get(row['city'],0)+stars
    
    # increment the running count in count
    count[row['city']]=count.get(row['city'],0)+1

# %%
star_sum['Anthem']
# Out:
# 208.0

# %% [markdown]
# Now we can calculate the average ratings.  Again, a dictionary makes a good container.

# %%
avg_stars = dict()
for city in star_sum:
    # calculate average star rating and store in avg_stars
    avg_stars[city]=star_sum[city]/count[city]

# %% [markdown]
# There should be 167 different cities:

# %% [markdown]
# We can get that list of tuples by converting the returned view object from the `items` method into a list.

# %% [markdown]
# ## Question 2: city_model

# %% [markdown]
# Now, let's build a custom estimator that will make a prediction based solely on the city of a venue.  It is tempting to hard-code the answers from the previous section into this model, but we're going to resist and do things properly.
#
# This custom estimator will have a `fit` method.  It will receive `data` as its argument `X` and `star_ratings` as `y`, and should repeat the calculation of the previous problem there.  Then the `predict` method can look up the average rating for the city of each record it receives.

# %%
from sklearn.base import BaseEstimator, RegressorMixin
import numpy as np

class CityRegressor(BaseEstimator, RegressorMixin):
    
    def __init__(self):
        self.avg_stars = dict()
    
    def fit(self, X, y):
        
        star_sum=defaultdict(int)
        count=defaultdict(int)
        
        for row,star in zip(X,y):
            star_sum[row['city']]=star_sum.get(row['city'],0)+star
            count[row['city']]=count[row['city']]+1
            
        avg_stars=defaultdict(int)
        for city in star_sum:
            avg_stars[city]=star_sum[city]/count[city]
        # Store the average rating per city in self.avg_stars
        self.avg_stars=avg_stars
        
        return self
    
    def predict(self, X):
        
        result = list()
        
        for row in X:
            if row['city'] in self.avg_stars:
                result.append(self.avg_stars[row['city']])
            else:
                result.append(sum(self.avg_stars.values())/len(self.avg_stars.values())) # replace with average if no city at training dataset
       
        return result

# %% [markdown]
# Now we can create an instance of our regressor and train it.

# %%
city_model = CityRegressor()
city_model.fit(data, star_ratings)
# Out:
# CityRegressor()

# %% [markdown]
# There is a problem, however.  What happens if we're asked to estimate the rating of a venue in a city that's not in our training set?
#
# 'Timbuktu' is not in city names, 'Madison' and 'Phoenix' are in the list of cities.

# %%
city_model.predict([{'city': 'Phoenix'}, {'city': 'Timbuktu'}, {'city': 'Madison'},{'city': 'Tehran'}])
# Out:
# [3.6702903946388683,
#  3.7127593360958078,
#  3.6457337883959045,
#  3.7127593360958078]

# %%
grader.score('ml__city_avg', list(avg_stars.items()))
# Out:
# ==================
# Your score: 1.0000
# ==================

# %% [markdown]
# ## Question 3: lat_long_model

# %% [markdown]
# You can imagine that a city-based model might not be sufficiently fine-grained. For example, we know that some neighborhoods are trendier than others.  Use the latitude and longitude of a venue as features that help you understand neighborhood dynamics.
#
# Since we need to select the appropriate columns from our dictionaries to build our latitude-longitude model, we will have to use scikit-learn's [`ColumnTransformer`](https://scikit-learn.org/stable/modules/generated/sklearn.compose.ColumnTransformer.html). However, the `ColumnTransformer` works with either NumPy arrays or pandas data frames. While we can convert our training data into a data frame easily, the test set the grader uses is a list of dictionaries. Thus, our first estimator in our workflow should be a transformer that converts a list of dictionaries into a pandas data frame.

# %%
import pandas as pd
from sklearn.base import TransformerMixin

class ToDataFrame(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        # This transformer doesn't need to learn anything about the data,
        # so it can just return self without any further processing
        return self
    
    def transform(self, X):
        
        # Return a pandas data frame from X
        df=pd.DataFrame(X)
        return df

# %% [markdown]
# Let's test out the transformer.

# %%
to_data_frame = ToDataFrame()
X_t = to_data_frame.fit_transform(data[:5])

# Check that our transformer properly transform the input data into a data frame
grader.check((X_t == pd.DataFrame(data[:5])).all(axis=None))
# Out:
# True

# %%
data[:5]
# Out:
# [{'business_id': 'vcNAWiLM4dR7D2nwwJ7nCA',
#   'full_address': '4840 E Indian School Rd\nSte 101\nPhoenix, AZ 85018',
#   'hours': {'Tuesday': {'close': '17:00', 'open': '08:00'},
#    'Friday': {'close': '17:00', 'open': '08:00'},
#    'Monday': {'close': '17:00', 'open': '08:00'},
#    'Wednesday': {'close': '17:00', 'open': '08:00'},
#    'Thursday': {'close': '17:00', 'open': '08:00'}},
#   'open': True,
#   'categories': ['Doctors', 'Health & Medical'],
#   'city': 'Phoenix',
#   'review_count': 7,
#   'name': 'Eric Goldberg, MD',
#   'neighborhoods': [],
#   'longitude': -111.983758,
#   'state': 'AZ',
#   'stars': 3.5,
#   'latitude': 33.499313,
#   'attributes': {'By Appointment Only': True},
#   'type': 'business'},
#  {'business_id': 'JwUE5GmEO-sH1FuwJgKBlQ',
#   'full_address': '6162 US Highway 51\nDe Forest, WI 53532',
#   'hours': {},
#   'open': True,
#   'categories': ['Restaurants'],
#   'city': 'De Forest',
#   'review_count': 26,
#   'name': 'Pine Cone Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.335844,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.238893,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': True,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': False},
#    'Caters': False,
#    'Noise Level': 'average',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': False},
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Alcohol': 'none',
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'uGykseHzyS5xAMWoN6YUqA',
#   'full_address': '505 W North St\nDe Forest, WI 53532',
#   'hours': {'Monday': {'close': '22:00', 'open': '06:00'},
#    'Tuesday': {'close': '22:00', 'open': '06:00'},
#    'Friday': {'close': '22:00', 'open': '06:00'},
#    'Wednesday': {'close': '22:00', 'open': '06:00'},
#    'Thursday': {'close': '22:00', 'open': '06:00'},
#    'Sunday': {'close': '21:00', 'open': '06:00'},
#    'Saturday': {'close': '22:00', 'open': '06:00'}},
#   'open': True,
#   'categories': ['American (Traditional)', 'Restaurants'],
#   'city': 'De Forest',
#   'review_count': 16,
#   'name': 'Deforest Family Restaurant',
#   'neighborhoods': [],
#   'longitude': -89.353437,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.252267,
#   'attributes': {'Take-out': True,
#    'Good For': {'dessert': False,
#     'latenight': False,
#     'lunch': False,
#     'dinner': False,
#     'breakfast': False,
#     'brunch': True},
#    'Caters': False,
#    'Noise Level': 'quiet',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Has TV': True,
#    'Outdoor Seating': False,
#    'Attire': 'casual',
#    'Ambience': {'romantic': False,
#     'intimate': False,
#     'touristy': False,
#     'hipster': False,
#     'divey': False,
#     'classy': False,
#     'trendy': False,
#     'upscale': False,
#     'casual': True},
#    'Waiter Service': True,
#    'Accepts Credit Cards': True,
#    'Good for Kids': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'LRKJF43s9-3jG9Lgx4zODg',
#   'full_address': '4910 County Rd V\nDe Forest, WI 53532',
#   'hours': {'Monday': {'close': '22:00', 'open': '10:30'},
#    'Tuesday': {'close': '22:00', 'open': '10:30'},
#    'Friday': {'close': '22:00', 'open': '10:30'},
#    'Wednesday': {'close': '22:00', 'open': '10:30'},
#    'Thursday': {'close': '22:00', 'open': '10:30'},
#    'Sunday': {'close': '22:00', 'open': '10:30'},
#    'Saturday': {'close': '22:00', 'open': '10:30'}},
#   'open': True,
#   'categories': ['Food',
#    'Ice Cream & Frozen Yogurt',
#    'Fast Food',
#    'Restaurants'],
#   'city': 'De Forest',
#   'review_count': 7,
#   'name': "Culver's",
#   'neighborhoods': [],
#   'longitude': -89.374983,
#   'state': 'WI',
#   'stars': 4.5,
#   'latitude': 43.251045,
#   'attributes': {'Take-out': True,
#    'Wi-Fi': 'free',
#    'Takes Reservations': False,
#    'Delivery': False,
#    'Parking': {'garage': False,
#     'street': False,
#     'validated': False,
#     'lot': True,
#     'valet': False},
#    'Wheelchair Accessible': True,
#    'Attire': 'casual',
#    'Accepts Credit Cards': True,
#    'Good For Groups': True,
#    'Price Range': 1},
#   'type': 'business'},
#  {'business_id': 'RgDg-k9S5YD_BaxMckifkg',
#   'full_address': '631 S Main St\nDe Forest, WI 53532',
#   'hours': {'Monday': {'close': '22:00', 'open': '11:00'},
#    'Tuesday': {'close': '22:00', 'open': '11:00'},
#    'Friday': {'close': '22:30', 'open': '11:00'},
#    'Wednesday': {'close': '22:00', 'open': '11:00'},
#    'Thursday': {'close': '22:00', 'open': '11:00'},
#    'Sunday': {'close': '21:00', 'open': '16:00'},
#    'Saturday': {'close': '22:30', 'open': '11:00'}},
#   'open': True,
#   'categories': ['Chinese', 'Restaurants'],
#   'city': 'De Forest',
#   'review_count': 3,
#   'name': 'Chang Jiang Chinese Kitchen',
#   'neighborhoods': [],
#   'longitude': -89.3437217,
#   'state': 'WI',
#   'stars': 4.0,
#   'latitude': 43.2408748,
#   'attributes': {'Take-out': True,
#    'Has TV': False,
#    'Outdoor Seating': False,
#    'Attire': 'casual'},
#   'type': 'business'}]

# %%
np.array([data[0]['latitude'], data[0]['longitude']])
# Out:
# array([  33.499313, -111.983758])

# %%
result = []
for i in range(len(X_t)):
    z=np.array(X_t['latitude'][i],X_t['longitude'][i])
    result.append(z)

# %%
X_t.columns
# Out:
# Index(['business_id', 'full_address', 'hours', 'open', 'categories', 'city',
#        'review_count', 'name', 'neighborhoods', 'longitude', 'state', 'stars',
#        'latitude', 'attributes', 'type'],
#       dtype='object')

# %% [markdown]
# Now we are ready to use `ColumnTransformer` and test it out.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.base import BaseEstimator
from sklearn.base import TransformerMixin

class ColumnSelectTransformer(BaseEstimator, TransformerMixin):
    
    def __init__(self,X=None):
        self.X = X  # We will need these in transform()
    
    def fit(self, X, y=None):
        # This transformer doesn't need to learn anything about the data,
        # so it can just return self without any further processing
        return self
    
    def transform(self, X):
        z3=list(zip(X['latitude'],X['longitude']))
        
        #result = [[ele['latitude'], ele['longitude']] for ele in X]
        # Return an array with the same number of rows as X and one
        # column for each in self.col_names
        return z3

# %%
import numpy as np
from sklearn.compose import ColumnTransformer

selector = ColumnSelectTransformer()
expected = np.array([data[0]['latitude'], data[0]['longitude']])

# Check that our selector returns just two columns, the latitude and longitude
grader.check((selector.fit_transform(X_t)[0] == expected).all())
# Out:
# True

# %% [markdown]
# Now, let's feed the output of the transformer in to a `KNeighborsRegressor`. As a sanity check, we'll test it with the first 5 rows.

# %%
from sklearn.neighbors import KNeighborsRegressor

# Training the model
data_transform = to_data_frame.transform(data)
data_transform = selector.fit_transform(data_transform)
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(data_transform, star_ratings)

# Making predictions
test_data = data[:5]
test_data_transform = to_data_frame.transform(test_data)
test_data_transform = selector.transform(test_data_transform)
knn.predict(test_data_transform)
# Out:
# array([4. , 4.2, 4. , 3.8, 4.2])

# %%
star_ratings[:5]
# Out:
# [3.5, 4.0, 4.0, 4.5, 4.0]

# %% [markdown]
# We are not ready to submit to the grader; there are two things we still need to do:
# 1. Wrap all the steps necessary to go from our data (list of dictionaries) to predicted ratings
# 1. Determine the optimal value for our predictor's hyperparameter
#
# For the first point, we will use a pipeline, ensuring that our model applies all the required transformations given the form of the input data. Remember that a pipeline is made with a list of `(step_name, estimator)` tuples.

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ('dataframe',ToDataFrame()),
    ('transform',ColumnSelectTransformer()) ,
    ('KNN',KNeighborsRegressor(n_neighbors=5)) ,
])

# %% [markdown]
# Now let's fit and predict.

# %%
pipe.fit(data, star_ratings)
pipe.predict(data[:5])
# Out:
# array([4. , 4.2, 4. , 3.8, 4.2])

# %%
star_ratings[:5]
# Out:
# [3.5, 4.0, 4.0, 4.5, 4.0]

# %% [markdown]
# Let's now focus on the second point. The `KNeighborsRegressor` takes the `n_neighbors` hyperparameter, which tells it how many nearest neighbors to average together when making a prediction. There is no reason to believe that 5 is the optimum value. We will need to determine a better value for this hyperparameter. A common approach is to use a hyperparameter searching tool such as [`GridSearchCV`](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html#sklearn.model_selection.GridSearchCV). You may need to refer back to the notebooks about the ways to interface searching tools and pipelines.

# %% [markdown]
# You should consider whether the data needs to be shuffled as it might not have been randomized. For example, the data could be ordered by a certain feature or by the labels. If you perform a train/test split with [`train_test_split`](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html#sklearn.model_selection.train_test_split), the data is shuffled by default. However, when using `GridSearchCV`, the folds are not shuffled when you use the default K-folds cross-validation.
#
# The code below will plot a rolling mean of the star ratings. Do you need to shuffle the data?

# %%
from pandas import Series
import matplotlib.pyplot as plt

plt.plot(Series.rolling(Series(star_ratings), window=1000).mean());

# %% [markdown]
# Once you've found a good value of `n_neighbors`, submit the model to the grader. Note, "good" is a relative measure here. The reference solution has an $R^2$ score of only 0.02. There is just rather little signal available for modeling.

# %% [markdown]
# # Optimize the Kneighbours

# %%
X=data
y=star_ratings

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ('dataframe',ToDataFrame()),
    ('transform',ColumnSelectTransformer()) ,
    ('KNN',KNeighborsRegressor()) ,
])

# %%
from sklearn.model_selection import GridSearchCV
lat_long_model= GridSearchCV(
    pipe,
    {'KNN__n_neighbors': list(range(80,150,10))},
    cv=10,  
    n_jobs=2
    )
lat_long_model.fit(data, star_ratings)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('dataframe', ToDataFrame()),
#                                        ('transform', ColumnSelectTransformer()),
#                                        ('KNN', KNeighborsRegressor())]),
#              n_jobs=2,
#              param_grid={'KNN__n_neighbors': [80, 90, 100, 110, 120, 130, 140]})

# %%
grader.score('ml__lat_long_model',  lat_long_model.predict)  # Edit to appropriate name
# Out:
# ==================
# Your score: 0.9975
# ==================

# %% [markdown]
# ### Evaluate Model Performance

# %% [markdown]
# ## Question 4: category_model

# %% [markdown]
# While location is important, we could also try seeing how predictive the
# venue's category is. Build an estimator that considers only the `'categories'` field of the data.
#
# The categories come as a list of strings, but the scikit-learn's predictors all need numeric input. We ultimately want to create a column in our feature matrix to represent every category. For a given row, only the columns that represent the categories it contains will be filled with a one, otherwise, it will be filled with a zero. The described method is similar to **one-hot encoding**, however, an observation/row can contain more than one "hot", non-zero, column.
#
# To achieve our encoding plan, we need to use scikit-learn's provides [`DictVectorizer`](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.DictVectorizer.html#sklearn.feature_extraction.DictVectorizer). This transformer takes a 1-D array of dictionaries and creates a column in the output matrix for each key in the dictionary and fills it with the value associated with it. Missing keys are filled with zeros. However, we need to build a transformer that takes an array of strings and returns an array of dictionaries with keys given by those strings and values of one. For example, it should transform `X_in` into `X_out`.

# %%
X_in = pd.Series([['a'], ['b', 'c']])
X_out = pd.Series([{'a': 1}, {'b': 1, 'c': 1}])

print(X_in)
print(X_out)
# Out:
# 0       [a]
# 1    [b, c]
# dtype: object
# 0            {'a': 1}
# 1    {'b': 1, 'c': 1}
# dtype: object

# %%
class DictEncoder(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        # X will be a pandas series. Return a pandas series of dictionaries
        d=[]
        for i in X:
            b={}
            for item in i:
                b[item]=i.count(item)
            d.append(b)
        return d

# %%
class ColumnSelectTransformer_categ(BaseEstimator, TransformerMixin):
    
    def __init__(self, col_names):
        self.col_names = col_names  # We will need these in transform()
    
    def fit(self, X, y=None):
        # This transformer doesn't need to learn anything about the data,
        # so it can just return self without any further processing
        return self
    
    def transform(self, X):
        result = []
        for ele in X:
            result.extend([ele[i] for i in self.col_names ])
        
        # Return an array with the same number of rows as X and one
        # column for each in self.col_names
        return result

# %%
cst = ColumnSelectTransformer_categ(['categories'])
z=cst.fit_transform(data)

# %% [markdown]
# Now, create a pipeline object of the two step transformation for the categories data. Afterwards, create a `ColumnTransformer` object that will use the aforementioned pipeline object to transform the `'categories'` field.

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import Ridge

pipe_cat=Pipeline([('transformer',ColumnSelectTransformer_categ(['categories'])),
               ('dict', DictEncoder()),
                ('vec',DictVectorizer(sparse=False)),
                #('tf_idf',sklearn.feature_extraction.text.TfidfTransformer())
                ('estimator', Ridge())])

# %%
#pipe_cat.get_params()

# %% [markdown]
# Finally, create a pipeline object that will
# 1. Convert our list of dictionaries into a data frame
# 1. Select the `'categories'` column and encode the data
# 1. Train a regularized linear model such as `Ridge`
#
# There will be a large number of features, one for each category, so there is a significant danger of overfitting. Use cross validation to choose the best regularization parameter.

# %%
from sklearn.model_selection import GridSearchCV

category_model= GridSearchCV(
    pipe_cat,
    {"estimator__alpha": [1.e-2, 1.e-1, 1.e0, 1.e+1, 1.e+2, 1.e+3]}, # range of hyperparameters to test
    cv=10,  # 10-fold cross validation
    n_jobs=2,  # run each hyperparameter in one of two parallel jobs
    )
category_model.fit(data, star_ratings)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('transformer',
#                                         ColumnSelectTransformer_categ(col_names=['categories'])),
#                                        ('dict', DictEncoder()),
#                                        ('vec', DictVectorizer(sparse=False)),
#                                        ('estimator', Ridge())]),
#              n_jobs=2,
#              param_grid={'estimator__alpha': [0.01, 0.1, 1.0, 10.0, 100.0,
#                                               1000.0]})

# %%
category_model.best_params_
# Out:
# {'estimator__alpha': 10.0}

# %%
grader.score('ml__category_model', category_model.predict)  # Edit to appropriate name
# Out:
# ==================
# Your score: 1.0055
# ==================

# %% [markdown]
# ### Evaluate Model Performance

# %% [markdown]
# **Extension:** Some categories (e.g., Restaurants) are not very specific. Others (Japanese sushi) are much more so.  One way to deal with this is with an measure call term frequency-inverse document frequency (tf-idf). Add in a [`TfidfTransformer`](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html) between the `DictVectorizer` and the linear model, and see if that improves performance.

# %% [markdown]
# ## Question 5: attribute_model

# %% [markdown]
# There is even more information in the attributes for each venue.  Let's build an estimator based on these.
#
# Venues attributes may be nested:
# ```python
# {
#   'Attire': 'casual',
#   'Accepts Credit Cards': True,
#   'Ambiance': {'casual': False, 'classy': False}
# }
# ```
# We wish to encode them in the same manner as our categories data using the `DictVectorizer`. Before we do so, we need to flatten the dictionary to a single level:
# ```python
# {
#   'Attire_casual' : 1,
#   'Accepts Credit Cards': 1,
#   'Ambiance_casual': 0,
#   'Ambiance_classy': 0
# }
# ```
# Build a custom transformer that flattens the dictionary for the `'attributes'` field. Similar to what was done before, create a model that properly encodes the attribute data and learns to predict the ratings.
#
# You may find it difficult to find a single regressor that does well enough. A common solution is to use a linear model to fit the linear part of some data, and use a non-linear model to fit the residual that the linear model can't fit. Build a custom predictor that takes as an argument two other predictors. It should use the first to fit the raw data and the second to fit the residuals of the first.

# %%
# !pip install flatten-dict
from flatten_dict.reducers import make_reducer
from flatten_dict import flatten

def flatendict(list_of_dictionaries):
    lst=[]
    for i in range(len(list_of_dictionaries)):
        d=flatten(list_of_dictionaries[i], reducer=make_reducer(delimiter='_'))
        lst.append(d)
    return lst
# Out:
# Collecting flatten-dict
#   Using cached flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: six<2.0,>=1.12 in /opt/conda/envs/data3/lib/python3.9/site-packages (from flatten-dict) (1.15.0)
# Installing collected packages: flatten-dict
# Successfully installed flatten-dict-0.4.2

# %%
#MAKE A FunctionTransformer from function flatendict to use in pipeline
from sklearn.preprocessing import FunctionTransformer

flatendict_transformer = FunctionTransformer(flatendict)

# %%
# Create the transformer to handle the attributes data

# Create the linear + non-linear ensemble predictor

# Create the attribute model

# %%
pipe_att = Pipeline([
    ('cst', ColumnSelectTransformer_categ(['attributes'])),
    ('flatendict', flatendict_transformer),
    ('vec',DictVectorizer(sparse=False)),
    ('estimator', Ridge())
    ])

# %%
attribute_est= GridSearchCV(
    pipe_att,
    {"estimator__alpha": [1.e-4, 1.e-3, 1.e-2, 1.e-1, 1.e0, 1.e+1, 1.e+2]},  # range of hyperparameters to test
    cv=10,  # 10-fold cross validation
    n_jobs=2,  # run each hyperparameter in one of two parallel jobs
)
attribute_est.fit(data, star_ratings)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('cst',
#                                         ColumnSelectTransformer_categ(col_names=['attributes'])),
#                                        ('flatendict',
#                                         FunctionTransformer(func=<function flatendict at 0x7f04c667bb80>)),
#                                        ('vec', DictVectorizer(sparse=False)),
#                                        ('estimator', Ridge())]),
#              n_jobs=2,
#              param_grid={'estimator__alpha': [0.0001, 0.001, 0.01, 0.1, 1.0,
#                                               10.0, 100.0]})

# %%
attribute_est.best_params_
# Out:
# {'estimator__alpha': 10.0}

# %%
class Residual_Predictor(BaseEstimator, TransformerMixin, RegressorMixin):
    
    def __init__(self):

        self.base = Ridge(alpha=0.1)
        self.residual = RandomForestRegressor(max_depth = 10, n_estimators = 150)
        
    def fit(self, X, y=None):
        self.base = self.base.fit(X, y)
        self.residual = self.residual.fit(X, np.array(y) - np.array(self.base.predict(X)))
        return self
    
    def predict(self, X):
        return np.array(self.base.predict(X))+np.array(self.residual.predict(X))

# %%
from sklearn.ensemble import RandomForestRegressor

attribute_model = Pipeline([
    ('cst', ColumnSelectTransformer_categ(['attributes'])),
    ('flatendict', flatendict_transformer),
    ('vec',DictVectorizer(sparse=False)),
    #('tf_idf',sklearn.feature_extraction.text.TfidfTransformer())
    ('estimator', Residual_Predictor())
    ])

attribute_model.fit(data, star_ratings)
# Out:
# Pipeline(steps=[('cst',
#                  ColumnSelectTransformer_categ(col_names=['attributes'])),
#                 ('flatendict',
#                  FunctionTransformer(func=<function flatendict at 0x7f04c667bb80>)),
#                 ('vec', DictVectorizer(sparse=False)),
#                 ('estimator', Residual_Predictor())])

# %%
grader.score('ml__attribute_model', attribute_model.predict)  # Edit to appropriate name
# Out:
# ==================
# Your score: 1.0069
# ==================

# %% [markdown]
# ### Evaluate Model Performance

# %% [markdown]
# ## Question 6: full_model

# %% [markdown]
# So far we have only built models based on individual features.  Now we will build an ensemble regressor that averages together the estimates of the four previous regressors.
#
# In order to use the existing models as input to a predictor, we will have to turn them into transformers; a predictor can only be in the final step of a pipeline. Build a custom `ModelTransformer` class that takes a predictor as an argument. When `fit` is called, the predictor should be fit. When `transform` is called, the predictor's `predict` method should be called, and its results returned as the transformation.
#
# Note that the output of the `transform` method should be a 2-D array with a single column in order for it to work well with the scikit-learn pipeline. If you're using NumPy arrays, you can use `.reshape(-1, 1)` to create a column vector. If you are just using Python lists, you will want a list of lists of single elements.

# %%
class ModelTransformer(BaseEstimator, TransformerMixin):
    
    def __init__(self, model):
        # What needs to be done here?
        self.model = model
    
    def fit(self, X, y):
        # Fit the stored predictor.
        # Question: what should be returned?
        return self
    
    def transform(self, X):
        # Use predict on the stored predictor as a "transformation".
        # Be sure to return a 2-D array.
        arr = self.model.predict(X)
        return [[item] for item in arr]

# %% [markdown]
# Let's now test it out on our `city_model`.

# %%
city_trans = ModelTransformer(city_model)
city_trans.fit(data, star_ratings)
X_t = city_trans.transform(data[:5])

# Check that the transformation output is a 2-D array with one column
grader.check(np.array(X_t).shape[-1] == 1)
# Out:
# True

# %%
y_pred = np.array(city_model.predict(data[:5]))

# Check that the transformation output is the same as the model's predictions
grader.check((y_pred.reshape(-1, 1) == X_t).all())
# Out:
# True

# %% [markdown]
# Create an instance of `ModelTransformer` for each of the previous four models. Combine these together in a single feature matrix with a
# [`FeatureUnion`](http://scikit-learn.org/stable/modules/generated/sklearn.pipeline.FeatureUnion.html#sklearn.pipeline.FeatureUnion).

# %%
from sklearn.pipeline import FeatureUnion


union = FeatureUnion([
        # FeatureUnion uses the same syntax as Pipeline
    ('city_trans',ModelTransformer(city_model)),
    ('latlon_trans', ModelTransformer( lat_long_model)),
    ('cat_trans', ModelTransformer(category_model)),
    ('att_trans', ModelTransformer(attribute_model)) 
    ])

# %% [markdown]
# Our `FeatureUnion` object should return a feature matrix with four columns.

# %%
union.fit(data, star_ratings)
X_t = union.transform(data[:5])

# Transformed data should have 5 rows and 4 columns
grader.check(X_t.shape == (5, 4))
# Out:
# True

# %% [markdown]
# Finally, use a pipeline to combine the feature union with a linear regression (or another model) to weight the predictions.

# %%
from sklearn.ensemble import RandomForestRegressor

full_model = Pipeline([
    ('union', FeatureUnion([
                            ('city_trans',ModelTransformer(city_model)),
                            ('latlon_trans', ModelTransformer( lat_long_model)),
                            ('cat_trans', ModelTransformer(category_model)),
                            ('att_trans', ModelTransformer(attribute_model))
                            ])),
    ('estimator', RandomForestRegressor())
    ])

# %%
full_model.estimator.get_params().keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_54/1212682547.py in <module>
# ----> 1 full_model.estimator.get_params().keys()
#
# AttributeError: 'Pipeline' object has no attribute 'estimator'

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 50, stop = 500, num = 10)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(3, 50, num = 11)]
max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# %%
param_grid = {'estimator__n_estimators': n_estimators,
               'estimator__max_features': max_features,
               'estimator__max_depth': max_depth,
               }

# %%
full_model_est= GridSearchCV(
    full_model,
    param_grid,  # range of hyperparameters to test
    cv=10,  # 10-fold cross validation
    n_jobs=2,  # run each hyperparameter in one of two parallel jobs
)

# %%
full_model_est.fit(data, star_ratings)
# Out:
# /opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 2400 fits failed out of a total of 2400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2400 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 681, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/pipeline.py", line 390, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/pipeline.py", line 348, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/joblib/memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/pipeline.py", line 1172, in fit_transform
#     results = self._parallel_func(X, y, fit_params, _fit_transform_one)
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/pipeline.py", line 1194, in _parallel_func
#     return Parallel(n_jobs=self.n_jobs)(
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/joblib/parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/joblib/parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/joblib/parallel.py", line 779, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/joblib/parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/utils/fixes.py", line 211, in __call__
#     return self.function(*args, **kwargs)
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "/opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/base.py", line 850, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#   File "/tmp/ipykernel_54/483902717.py", line 15, in transform
#   File "/tmp/ipykernel_54/386803245.py", line 34, in predict
# ZeroDivisionError: division by zero
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_54/1550277533.py in <module>
# ----> 1 full_model_est.fit(data, star_ratings)
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     924             refit_start_time = time.time()
#     925             if y is not None:
# --> 926                 self.best_estimator_.fit(X, y, **fit_params)
#     927             else:
#     928                 self.best_estimator_.fit(X, **fit_params)
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     388         """
#     389         fit_params_steps = self._check_fit_params(**fit_params)
# --> 390         Xt = self._fit(X, y, **fit_params_steps)
#     391         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     392             if self._final_estimator != "passthrough":
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     346                 cloned_transformer = clone(transformer)
#     347             # Fit or load from cache the current transformer
# --> 348             X, fitted_transformer = fit_transform_one_cached(
#     349                 cloned_transformer,
#     350                 X,
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     347
#     348     def __call__(self, *args, **kwargs):
# --> 349         return self.func(*args, **kwargs)
#     350
#     351     def call_and_shelve(self, *args, **kwargs):
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     891     with _print_elapsed_time(message_clsname, message):
#     892         if hasattr(transformer, "fit_transform"):
# --> 893             res = transformer.fit_transform(X, y, **fit_params)
#     894         else:
#     895             res = transformer.fit(X, y, **fit_params).transform(X)
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#    1170             sum of `n_components` (output dimension) over transformers.
#    1171         """
# -> 1172         results = self._parallel_func(X, y, fit_params, _fit_transform_one)
#    1173         if not results:
#    1174             # All transformers are None
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/pipeline.py in _parallel_func(self, X, y, fit_params, func)
#    1192         transformers = list(self._iter())
#    1193
# -> 1194         return Parallel(n_jobs=self.n_jobs)(
#    1195             delayed(func)(
#    1196                 transformer,
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     209     def __call__(self, *args, **kwargs):
#     210         with config_context(**self.config):
# --> 211             return self.function(*args, **kwargs)
#     212
#     213
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     891     with _print_elapsed_time(message_clsname, message):
#     892         if hasattr(transformer, "fit_transform"):
# --> 893             res = transformer.fit_transform(X, y, **fit_params)
#     894         else:
#     895             res = transformer.fit(X, y, **fit_params).transform(X)
#
# /opt/conda/envs/data3/lib/python3.9/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     848         else:
#     849             # fit method of arity 2 (supervised transformation)
# --> 850             return self.fit(X, y, **fit_params).transform(X)
#     851
#     852
#
# /tmp/ipykernel_54/483902717.py in transform(self, X)
#      13         # Use predict on the stored predictor as a "transformation".
#      14         # Be sure to return a 2-D array.
# ---> 15         arr = self.model.predict(X)
#      16         return [[item] for item in arr]
#      17
#
# /tmp/ipykernel_54/386803245.py in predict(self, X)
#      32                 result.append(self.avg_stars[row['city']])
#      33             else:
# ---> 34                 result.append(sum(self.avg_stars.values())/len(self.avg_stars.values())) # replace with average if no city at training dataset
#      35
#      36         return result
#
# ZeroDivisionError: division by zero

# %%
full_model.fit(data, star_ratings)

# %%
grader.score('ml__full_model', full_model.predict)  # Edit to appropriate name

# %% [markdown]
# ### Evaluate Model Performance

# %% [markdown]
# **Extension:** Try a non-linear model such as [`RandomForestRegressor`](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html#sklearn.ensemble.RandomForestRegressor) to blend the predictions of the four models. Are you able to get better results? If so, what do you think it's learning how to do?

# %% [markdown]
# *Copyright &copy; 2021 Pragmatic Institute. This content is licensed solely for personal use. Redistribution or publication of this material is strictly prohibited.*
